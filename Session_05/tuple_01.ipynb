# %% [markdown]
# ## Tuple

# %% [markdown]
# A tuple in Python is similar to list. The difference between the two is that we can not change the elements in tuple once it's assigned whereas we can change the elements of list.
# In short, a tuple is an immutable list. A tuple can not be changed in any way once it's created.
#
# ### Characterstics
# - Ordered
# - Immutable
# - Allows duplicate

# %% [markdown]
# <img src="images/list_tuple_com.png" width="70%"> <br>
# Immutability is the fundamental difference. However, because tuples are immutable, they are more memory-efficient, slightly faster, hashable (can be used as dictionary keys), and are typically used for fixed data, whereas lists are used for data that needs to change.

# %% [markdown]
# ## Plan of attack.

# %% [markdown]
# - Creating a tuple.
# - Accessing a tuple.
# - Editing items.
# - Adding items.
# - Deleting items.
# - Operations on Tuple.
# - Tuple Functions.

# %% [markdown]
# ## Creating Tuples

# %%
# Empty
t1 = ()
print(t1)
# Out:
# ()

# %%
# Creating a tuple with single item. 
t2 = ('hello') # Here it will create problem.
print(type(t2)) 
t2 = ('hello',) # This is the correct way.
print(t2)
print(type(t2))
# Out:
# <class 'str'>
# ('hello',)
# <class 'tuple'>

# %%
# Creating Homogeneuous tuple.
t3 = (1,2,3,4,5)
print(t3)
# Hetrogeneous tuple.
t4 = (1,2.5,True,[1,2,3])
print(t4)
# Out:
# (1, 2, 3, 4, 5)
# (1, 2.5, True, [1, 2, 3])

# %%
# 2D Tuple.
t5 = (1,2,3,(4,5))
print(t5)
# Out:
# (1, 2, 3, (4, 5))

# %%
# Using Type Conversion.
t6 = tuple('hello')
print(t6)
# Out:
# ('h', 'e', 'l', 'l', 'o')
