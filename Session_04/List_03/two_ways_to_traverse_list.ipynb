# %% [markdown]
# ## Item wise.

# %%
L = [1,2,3,4]

for i in L:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Index wise.

# %%
L = [1,2,3,4]

for i in range(0, len(L)):
    print(L[i])
# Out:
# 1
# 2
# 3
# 4
