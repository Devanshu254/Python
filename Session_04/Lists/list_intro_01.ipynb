# %% [markdown]
# #### List
# - What are Lists?
# - Lists Vs Arrays
# - Characterstics of a List
# - How to create a list
# - Access items from a List
# - Editing items in a List
# - Deleting items from a List
# - Operations on Lists
# - Functions on Lists

# %% [markdown]
# What are Lists
# - List is a data type where you can store multiple items under 1 name. More technically, lists act like dynamic arrays which means you can add more items on the fly.

# %% [markdown]
# <img src="images/image.png" width="60%">

# %% [markdown]
# #### Arrays vs List
# <img src="images/array_vs_list.png" width="60%">

# %% [markdown]
# #### Arrays Vs List time comparision.
# <img src="images/arrays_list_time_comparision.png" width="70%">

# %% [markdown]
# id() functions tells the memory address. By using id() we can find out the memory address of below variable.

# %%
a = 2
print(id(a))
# Out:
# 140712475441624

# %%
L = [1,2,3]

print(id(L))
print(id(L[0]))
print(id(L[1]))
print(id(L[2]))
print(id(1))
print(id(2))
print(id(3))
# Out:
# 2638324108544
# 140712475441592
# 140712475441624
# 140712475441656
# 140712475441592
# 140712475441624
# 140712475441656

# %% [markdown]
# #### Visual Represenation of above code.
# <img src="images/list_elements_storage.png" width="70%">
