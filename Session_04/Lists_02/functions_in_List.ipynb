# %% [markdown]
# ## Functions
# - len/min/max/sorted.
# - count.
# - index.
# - reverse.
# - sort (vs sorted).
# - copy.

# %% [markdown]
# ## len/min/max/sorted.

# %%
L = [2,1,5,7,0]
print(len(L))
print(min(L)) #If we have homogeneous data.
print(max(L))
print(sorted(L))
print(sorted(L, reverse=True))
# Out:
# 5
# 0
# 7
# [0, 1, 2, 5, 7]
# [7, 5, 2, 1, 0]
