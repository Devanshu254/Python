# %% [markdown]
# ### Python is an interpreted language.
# <img src="images/python_working.png" width="70%">

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World", 1, 1.5, True)
# Out:
# Hello World 1 1.5 True

# %%
# Seperator keyword.
print("Hello World", 1, 1.2, True, sep="/")
# Out:
# Hello World/1/1.2/True

# %% [markdown]
# end is a parameter of python's print function.
# By default, every print() ends with a new line(\n).

# %%
# Using end keyword.
print("Hello", end="-")
print("Devanshu")
# Out:
# Hello-Devanshu
