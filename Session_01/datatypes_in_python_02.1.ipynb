# %% [markdown]
# ## List

# %%
employees = ["Devanshu", "Rahul", "Priya"]

# %% [markdown]
# Characteristics
#
#  ✅ Ordered <br>
#  ✅ Mutable (can change) <br>
#  ✅ Allows duplicates <br>

# %%
employees.append("Amit")
print(employees)
# Out:
# ['Devanshu', 'Rahul', 'Priya', 'Amit', 'Amit']

# %%
transactions = [
    "Deposit",
    "Withdraw",
    "Transfer"
]

# %% [markdown]
# A list is used because order matters and transactions can repeat.

# %% [markdown]
# ## Tuple ()

# %%
coordinates = (17.3850, 78.4867)

# %% [markdown]
# Characteristics
#
#  ✅ Ordered <br>
#  ❌ Cannot change (Immutable) <br>
#  ✅ Faster than lists for fixed data <br>

# %% [markdown]
# ### Real-world Use Cases
# - GPS Coordinates

# %%
location = (17.3850, 78.4867)

# %% [markdown]
# ## Set {}

# %%
skills = {"Python", "Java", "SQL"}

# %% [markdown]
# Characteristics
#
#  ✅ No duplicates <br>
#  ✅ Very fast searching <br>
#  ❌ No order guarantee <br>

# %% [markdown]
# Real-world Use Cases <br>
# Remove Duplicates

# %%
emails = [
    "a@gmail.com",
    "a@gmail.com",
    "b@gmail.com"
]

unique_emails = set(emails)

# %% [markdown]
# Industry Example <br>
#
# Fraud detection systems:

# %%
blocked_cards = {
    "1234",
    "5678",
    "9999"
}
