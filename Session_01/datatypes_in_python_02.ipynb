# %%
# Integer
print(8)
print(1e308) # 1*10^308
print(1e309)
# Out:
# 8
# 1e+308
# inf

# %%
# Decimal/Float
print(8.55)
print(1.7e308)
print(1.7e309)
# Out:
# 8.55
# 1.7e+308
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print("Hello World")
# Out:
# Hello World

# %%
# Complex Number
print(5+6j)
# Out:
# (5+6j)

# %%
# List -> C -> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({"Name": "Devanshu", "Gender": "Male"})
# Out:
# {'Name': 'Devanshu', 'Gender': 'Male'}

# %%
# Type
print(type(6))
# Out:
# <class 'int'>
